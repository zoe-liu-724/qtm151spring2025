# %% [markdown]
# # Assignment 6

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your Emory code below

# %%
print(2583239)
# Out:
# 2583239

# %% [markdown]
# <font size = "5">
#
# Import the "pandas" and "matplotlib.pyplot" libraries

# %%
# Write your answer here:
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = "5">
#
# (a) Functions
#
# <font size = "3">
#
# - Read the dataset labelled features.csv.
# - Create a ``` lambda ``` function that checks if displacement $>$ 200
# - Create a new list that shows true if displacement $>$ 200 and false if displacement $\leq$ 200.
# - Count how many cars have displacement $> 200$.
#
# To get full credit use either the apply or the map function (see Lectures 7 and 8)

# %%
# Write your answer here:
features = pd.read_csv("data/features.csv")
features

fn_check = lambda displacement: displacement > 200
features["displacement_200"] = features["displacement"].apply(fn_check)
print(len(features.query("displacement_200 == True")))
# Out:
# 158

# %% [markdown]
# <font size = "5">
#
# (b) Subsetting Data
#
# <font size = "3" >
#
# - Read the dataset labelled features.csv.
# - Define a global variable called ```threshold``` that takes the value 2588
# - Subset the data to get one dataset with weight $>$ threshold and another with weight $\le$ 2588. Use the ```.query()``` function.
# - Compute the mean acceleration for each of these datasets. Note: Review how to define a gloabl variable inside ```.query()```

# %%
# Write your answer here:
features
threshold = 2588
over_threshold = features.query("weight > @threshold")
below_threshold = features.query("weight <= @threshold")
print(over_threshold["acceleration"].mean())
print(below_threshold["acceleration"].mean())
# Out:
# 14.972457627118644
# 16.435802469135798

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Use ".sort_values()" to order the "Age" column from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your answer here:
fifa = pd.read_csv("data/fifa23_players_basic.csv")
age_asc = fifa.sort_values(by = "Age", ascending = True)
age_asc_5 = age_asc.iloc[0:5 , : ]

# %% [markdown]
# <font size = "5">
#
# (d) Use queries + global variables
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Compute the mean of the column "Wage(in Euro)" and store it as a variable
# - Subset the players whose value is above the mean value using ".query()"
#
#
# HINT: Remember that there is a special syntax for when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your answer here:
fifa
avg_wage = fifa["Wage(in Euro)"].mean()
fifa.query("`Wage(in Euro)` > @avg_wage")
# Out:
#                  Known As                 Full Name  Overall  Potential  \
# 0                L. Messi              Lionel Messi       91         91
# 1              K. Benzema             Karim Benzema       91         91
# 2          R. Lewandowski        Robert Lewandowski       91         91
# 3            K. De Bruyne           Kevin De Bruyne       91         91
# 4               K. Mbappé             Kylian Mbappé       91         95
# ...                   ...                       ...      ...        ...
# 14279            A. Lewis                Adam Lewis       61         65
# 15117           B. Knight                Ben Knight       60         74
# 15441  T. Suengchitthawon  Thanawat Suengchitthawon       60         70
# 15957          P. Glatzel              Paul Glatzel       59         65
# 16157      C. Chukwuemeka         Caleb Chukwuemeka       58         71
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# ...

# %% [markdown]
# <font size = "5">
#
# (e) Plot by Category
#
# <font size = "3">
#
# Read the "data/wdi_urban.csv" dataset.
#
#   This contains data from 1980 and 2020.
#
# - **Create a list with the unique values of "year"**
#
# - **Create a plot with a ...**
#     - Histogram of "prop_urbanpopulation" for each year
#     - Set the histogram option `alpha = 0.5` for transparency
#     - All the histograms should be overlapping
#     - Create a legend with the list of years
#     - Label the axes and the title

# %%
# Write your answer here:
wdi_urban = pd.read_csv("data/wdi_urban.csv")
list_unique_years = pd.unique(wdi_urban["year"])
for year_num in list_unique_years:
    data = wdi_urban.query("year == @year_num")
    plt.hist(x = data["prop_urbanpopulation"], alpha = 0.5)
plt.xlabel("Proportion of Urban Population")
plt.ylabel("Frequency")
plt.title("Distribution of Urban Population by Years")
plt.legend(labels = list_unique_years,
           title  = "Years")
plt.show()
